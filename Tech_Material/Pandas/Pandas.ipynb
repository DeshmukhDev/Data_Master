# %% [markdown]
# # supriya notes pandas page - 21

# %%
import pandas as pd

# %%
import shutil
import os

# %%
target = 'C:/Users/deshm/OneDrive/Documents'
book_Name = 'Pandas.ipynb'
target_path = os.path.join(target,book_Name)
shutil.copy2(book_Name, target_path)
# Out:
# 'C:/Users/deshm/OneDrive/Documents\\Pandas.ipynb'

# %% [markdown]
# # short keys --> shift + tab  -- documentation

# %%
df = pd.DataFrame({
    "Name":["vaishnavi", "Radhika","Radhika", "Manali","Atharva","Sagar","Vedant","Madhura","abhishek"],
    "age":[11,22,33,44,55,76,77,98,90],
    "sex":["female","female","female","female","male","male","male","female","male"]
    
    
})
df
# Out:
#         Name  age     sex
# 0  vaishnavi   11  female
# 1    Radhika   22  female
# 2    Radhika   33  female
# 3     Manali   44  female
# 4    Atharva   55    male
# 5      Sagar   76    male
# 6     Vedant   77    male
# 7    Madhura   98  female
# 8   abhishek   90    male

# %%
#You can create a Series from scratch as well:
ages = pd.Series([22, 35, 58], name="age")
ages
# Out:
# 0    22
# 1    35
# 2    58
# Name: age, dtype: int64

# %% [markdown]
# # Each column in a DataFrame is a Series
# # Datapoints - rows

# %%
df["age"]
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# 5    76
# 6    77
# 7    98
# 8    90
# Name: age, dtype: int64

# %%
#max of age:
df["age"].max()
# Out:
# 98

# %%
df.describe()
# Out:
#              age
# count   9.000000
# mean   56.222222
# std    30.853597
# min    11.000000
# 25%    33.000000
# 50%    55.000000
# 75%    77.000000
# max    98.000000

# %%
df1=df["Name"]

# %%
df1.describe()
# Out:
# count           9
# unique          8
# top       Radhika
# freq            2
# Name: Name, dtype: object

# %% [markdown]
# # object - str, char

# %%
df2 = pd.DataFrame({'categorical': pd.Categorical(['d','e','f']),
                   'numeric': [1, 2, 3],
                   'object': ['a', 'b', 'c']
                  })
df2
# Out:
#   categorical  numeric object
# 0           d        1      a
# 1           e        2      b
# 2           f        3      c

# %% [markdown]
# # multiple col fetch

# %%
df2[['object','numeric']]
# Out:
#   object  numeric
# 0      a        1
# 1      b        2
# 2      c        3

# %% [markdown]
# # single col fetch

# %%
df2.numeric
# Out:
# 0    1
# 1    2
# 2    3
# Name: numeric, dtype: int64

# %% [markdown]
# # REMEMBER
# 1. Import the package, aka import pandas as pd
#
# 2. A table of data is stored as a pandas DataFrame
#
# 3. Each column in a DataFrame is a Series
#
# 4. You can do things by applying a method to a DataFrame or Series

# %%
file_path = r'C:\Users\deshm\OneDrive\Documents\Pandas\titanic.xlsx'

df3 = pd.read_excel(file_path,sheet_name='Sheet2')
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # skip columns:
# # 1. Not In = te sodun baki che col
# # 2. In = j col dile te yetil
# # 3. Drop()

# %%
# new = df3[[col for col in df3.columns if col  not in ['Fare', 'Embarked']]]

new

# %%
new1 = df3[[col for col in df3.columns if col in ['Fare', 'Embarked']]]

new1
# Out:
#          Fare Embarked
# 0      7.8292        Q
# 1      7.0000        S
# 2      9.6875        Q
# 3      8.6625        S
# 4     12.2875        S
# ..        ...      ...
# 413    8.0500        S
# 414  108.9000        C
# 415    7.2500        S
# 416    8.0500        S
# 417   22.3583        C
#
# [418 rows x 2 columns]

# %%
new2 = df3.drop(columns=['Fare', 'Name'])
new2
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            892         0       3    male  34.5      0      0
# 1            893         1       3  female  47.0      1      0
# 2            894         0       2    male  62.0      0      0
# 3            895         0       3    male  27.0      0      0
# 4            896         1       3  female  22.0      1      1
# ..           ...       ...     ...     ...   ...    ...    ...
# 413         1305         0       3    male   NaN      0      0
# 414         1306         1       1  female  39.0      0      0
# 415         1307         0       3    male  38.5      0      0
# 416         1308         0       3    male   NaN      0      0
# 417         1309         0       3    male   NaN      1      1
#
#                  Ticket Cabin Embarked Country
# 0                330911   NaN        Q     USA
# 1                363272   NaN        S  Canada
# 2                240276   NaN        Q      UK
# ...

# %% [markdown]
# # head -- > initials columns (top-down approach)
# # tail --> last columns (bottom-up approach)

# %%
df3.shape
# Out:
# (418, 12)

# %%
df3.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df3.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# ...

# %%
df3.tail(2)
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex  Age  \
# 416         1308         0       3       Ware, Mr. Frederick  male  NaN
# 417         1309         0       3  Peter, Master. Michael J  male  NaN
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 416      0      0  359309   8.0500   NaN        S
# 417      1      1    2668  22.3583   NaN        C

# %%
# To fetch Column:
df3['Age']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
# To fetch all Columns:
df3.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# value_counts(): is used to count the occurrences of each unique value in a Pandas Series.
df3['Age'].value_counts()
# Out:
# 21.0    17
# 24.0    17
# 22.0    16
# 30.0    15
# 18.0    13
#         ..
# 76.0     1
# 28.5     1
# 22.5     1
# 62.0     1
# 38.5     1
# Name: Age, Length: 79, dtype: int64

# %%
# unique() : is used to obtain an array of the distinct (unique) values in a Pandas Series.
df3.Name.unique()
# Out:
# array(['Kelly, Mr. James', 'Wilkes, Mrs. James (Ellen Needs)',
#        'Myles, Mr. Thomas Francis', 'Wirz, Mr. Albert',
#        'Hirvonen, Mrs. Alexander (Helga E Lindqvist)',
#        'Svensson, Mr. Johan Cervin', 'Connolly, Miss. Kate',
#        'Caldwell, Mr. Albert Francis',
#        'Abrahim, Mrs. Joseph (Sophie Halaut Easu)',
#        'Davies, Mr. John Samuel', 'Ilieff, Mr. Ylio',
#        'Jones, Mr. Charles Cresson',
#        'Snyder, Mrs. John Pillsbury (Nelle Stevenson)',
#        'Howard, Mr. Benjamin',
#        'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)',
#        'del Carlo, Mrs. Sebastiano (Argenia Genovesi)',
#        'Keane, Mr. Daniel', 'Assaf, Mr. Gerios',
#        'Ilmakangas, Miss. Ida Livija',
#        'Assaf Khalil, Mrs. Mariana (Miriam")"', 'Rothschild, Mr. Martin',
#        'Olsen, Master. Artur Karl',
#        'Flegenheim, Mrs. Alfred (Antoinette)',
#        'Williams, Mr. Richard Norris II',
# ...

# %%
# To fetch all Columns:

column_names = df3.columns.tolist()

column_names
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
#To find length:
len (df3['Name'])
# Out:
# 418

# %%
# describe:  method is used to generate descriptive statistics 
df3.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
countries = pd.Series(['USA', 'Canada', 'UK','india','china','UK','Japan','Russia']* len(df3))  

# Add the 'Country' column to the Titanic dataset
df3['Country'] = countries

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
pclass_3_rows = df3[df3['Pclass'] == 3]
pclass_3_rows
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# ..           ...       ...     ...
# 412         1304         1       3
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
row_Parch = df3[df3['Parch'] == 1]
row_Parch
# Out:
#      PassengerId  Survived  Pclass  \
# 4            896         1       3
# 7            899         0       2
# 21           913         0       3
# 23           915         0       1
# 26           918         1       1
# 40           932         0       3
# 52           944         1       2
# 55           947         0       3
# 80           972         0       3
# 89           981         0       2
# 104          996         1       3
# 117         1009         1       3
# 125         1017         1       3
# 149         1041         0       2
# 150         1042         1       1
# 161         1053         0       3
# 165         1057         1       3
# 181         1073         0       1
# 184         1076         1       1
# 186         1078         1       2
# 192         1084         0       3
# 203         1095         1       2
# 217         1109         0       1
# 218         1110         1       1
# 238         1130         1       2
# ...

# %% [markdown]
# # Rename the col: dict {}format mdhe dyava lagta

# %%
df4 = df3.rename(columns={'Age': 'Years'})
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  Years  SibSp  \
# 0                                Kelly, Mr. James    male   34.5      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female   47.0      1
# 2                       Myles, Mr. Thomas Francis    male   62.0      0
# 3                                Wirz, Mr. Albert    male   27.0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22.0      1
# ..                                            ...     ...    ...    ...
# ...

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df3 = df3.rename(columns={'Years': 'Age'})
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # New col add krycha asel n ti valuse sglya rows la apply zali phij
#
#
#
# # Add the new 'Country' column to the DataFrame

# %%
countries=df3['Country']
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # particular country pahij asel tr

# %%
china = df3[df3['Country'] == 'Russia']
china
# Out:
#      PassengerId  Survived  Pclass  \
# 7            899         0       2
# 15           907         1       2
# 23           915         0       1
# 31           923         0       2
# 39           931         0       3
# 47           939         0       3
# 55           947         0       3
# 63           955         1       3
# 71           963         0       3
# 79           971         1       3
# 87           979         1       3
# 95           987         0       3
# 103          995         0       3
# 111         1003         1       3
# 119         1011         1       2
# 127         1019         1       3
# 135         1027         0       3
# 143         1035         0       2
# 151         1043         0       3
# 159         1051         1       3
# 167         1059         0       3
# 175         1067         1       2
# 183         1075         0       3
# 191         1083         0       1
# 199         1091         1       3
# ...

# %%
male= df3[df3['Sex'] == 'male']
male
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %% [markdown]
# #### To give a path / or r

# %% [markdown]
# # 1. creating a dataframe by using tuple

# %%
emp_data= [(1,"vaish",23),(2,"manali",34),(3,"hgh",43)]
emp_data
d1= pd.DataFrame(emp_data)
d1
# Out:
#    0       1   2
# 0  1   vaish  23
# 1  2  manali  34
# 2  3     hgh  43

# %% [markdown]
# # 2. give name to column

# %%
d1=pd.DataFrame(emp_data,columns=['id','name','age'])
d1
# Out:
#    id    name  age
# 0   1   vaish   23
# 1   2  manali   34
# 2   3     hgh   43

# %% [markdown]
# # 1. In Windows, if you have the CSV file open (e.g. in Excel), and you run the script it cannot save to X_Data.csv since the file is in use and raises the PermissionError.

# %% [markdown]
# # 2. we can't access multiple CSV files like particular sheet use excel file for multiple files.

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 1. Dataframe --> tabular structure of data (rows and cols)
# 2. Delimeter -->  such as a mark or symbol used to show the beginning or end of separate elements e.g .csv file separated by (,)

# %%
df3.head(3) # default first 5 cols
df3.tail(2) # default last 5 cols
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex  Age  \
# 416         1308         0       3       Ware, Mr. Frederick  male  NaN
# 417         1309         0       3  Peter, Master. Michael J  male  NaN
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 416      0      0  359309   8.0500   NaN        S
# 417      1      1    2668  22.3583   NaN        C

# %% [markdown]
# # 3. data as a text or string dyaycha asel tr "dict " {} mdhech dyava lagnr

# %%
emp = {"In each row of the included datasets(train.csv and test.csv), products X(description_x) and Y(description_y) are considered to refer to the same security(same_security) if they have the same ticker(ticker_x,ticker_y), even if the descriptions don't exactly match. You can make use of these descriptions to predict whether each pair in the test set also refers to the same security."}
d2=pd.DataFrame(emp,columns=['id'])
d2
# Out:
#                                                   id
# 0  In each row of the included datasets(train.csv...

# %% [markdown]
# # 4. data from dict: all keys will acts as a columns

# %%
pred = [
       {'prod_name':'gold','price':34444,'packing':2011},
       {'prod_name':'gold', 'price':34444,'packing':2011},
       {'prod_name':'silver', 'price':343244,'packing':2021},
       {'prod_name':'copper', 'price':34844,'packing':2018}
]
d3= pd.DataFrame(pred)
d3
# Out:
#   prod_name   price  packing
# 0      gold   34444     2011
# 1      gold   34444     2011
# 2    silver  343244     2021
# 3    copper   34844     2018

# %% [markdown]
# # we can fetch data feom html,api,excel,csv,s3,dict,tuple

# %%
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)'
table = pd.read_html(url)[5]
table
# Out:
#               vteEconomic classification of countries  \
# 0   Developed country Developing country Least dev...
# 1                                   Three-World Model
# 2                        Gross domestic product (GDP)
# 3                                             Nominal
# 4                       Purchasing power parity (PPP)
# 5                         Gross national income (GNI)
# 6                                               Wages
# 7                                              Wealth
# 8                             Other national accounts
# 9                                   Human development
# 10                                     Digital divide
# 11       Net international investment position (NIIP)
# 12                    Economics portalʥ World portal
#
#             vteEconomic classification of countries.1
# 0   Developed country Developing country Least dev...
# 1   First World Second World Third World Fourth World
# ...

# %%
# Save as a excel: direct test1 current location vr create honr 

table.to_excel('test1.xlsx',index=False)
table
# Out:
#               vteEconomic classification of countries  \
# 0   Developed country Developing country Least dev...
# 1                                   Three-World Model
# 2                        Gross domestic product (GDP)
# 3                                             Nominal
# 4                       Purchasing power parity (PPP)
# 5                         Gross national income (GNI)
# 6                                               Wages
# 7                                              Wealth
# 8                             Other national accounts
# 9                                   Human development
# 10                                     Digital divide
# 11       Net international investment position (NIIP)
# 12                    Economics portalʥ World portal
#
#             vteEconomic classification of countries.1
# 0   Developed country Developing country Least dev...
# 1   First World Second World Third World Fourth World
# ...

# %%
type(table)
# Out:
# pandas.core.frame.DataFrame

# %%
# To fine sixe(shape)
table.shape
# Out:
# (13, 2)

# %%
#to find type
table.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_125956\181213077.py in <module>
#       1 #to find type
# ----> 2 table.dtypes
#
# NameError: name 'table' is not defined

# %%
dates = pd.date_range("20130101", periods=6)

# %%
ee=pd.DataFrame(dates)
ee
# Out:
#            0
# 0 2013-01-01
# 1 2013-01-02
# 2 2013-01-03
# 3 2013-01-04
# 4 2013-01-05
# 5 2013-01-06

# %%
dates.index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_125956\1086983301.py in <module>
# ----> 1 dates.index
#
# AttributeError: 'DatetimeIndex' object has no attribute 'index'
